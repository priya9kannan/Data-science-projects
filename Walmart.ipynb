# %% [markdown]
# https://drive.google.com/file/d/1ntws2rEMM3JeXyEalcl4FPn_cktfu8Jk/view?usp=sharing

# %%
# !gdown 1ntws2rEMM3JeXyEalcl4FPn_cktfu8Jk
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ntws2rEMM3JeXyEalcl4FPn_cktfu8Jk
# To: C:\Users\91944\walmart.csv
#
#   0%|          | 0.00/23.0M [00:00<?, ?B/s]
#   5%|4         | 1.05M/23.0M [00:00<00:04, 5.49MB/s]
#   9%|9         | 2.10M/23.0M [00:00<00:03, 5.32MB/s]
#  14%|#3        | 3.15M/23.0M [00:00<00:03, 5.37MB/s]
#  18%|#8        | 4.19M/23.0M [00:00<00:03, 5.34MB/s]
#  23%|##2       | 5.24M/23.0M [00:00<00:03, 5.70MB/s]
#  27%|##7       | 6.29M/23.0M [00:01<00:02, 5.76MB/s]
#  32%|###1      | 7.34M/23.0M [00:01<00:02, 5.89MB/s]
#  36%|###6      | 8.39M/23.0M [00:01<00:02, 6.10MB/s]
#  41%|####      | 9.44M/23.0M [00:01<00:02, 6.69MB/s]
#  48%|####7     | 11.0M/23.0M [00:01<00:01, 8.03MB/s]
#  55%|#####4    | 12.6M/23.0M [00:01<00:01, 8.85MB/s]
#  61%|######1   | 14.2M/23.0M [00:01<00:00, 9.61MB/s]
#  71%|#######   | 16.3M/23.0M [00:02<00:00, 11.4MB/s]
#  80%|#######9  | 18.4M/23.0M [00:02<00:00, 12.8MB/s]
#  87%|########6 | 19.9M/23.0M [00:02<00:00, 10.9MB/s]
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
w=pd.read_csv("walmart.csv")
w
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                               2               0                 3      8370
# ...

# %%
w.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category              0
# Purchase                      0
# dtype: int64

# %%
w.isnull().any().any()
# Out:
# False

# %% [markdown]
# Observations on shape of data, data types of all the attributes, conversion of categorical attributes to 'category' (If required), statistical summary

# %%
w.shape
# Out:
# (550068, 10)

# %%
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category            550068 non-null  int64
#  9   Purchase                    550068 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 42.0+ MB

# %%
w.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category  \
# count  5.500680e+05  550068.000000   550068.000000     550068.000000
# mean   1.003029e+06       8.076707        0.409653          5.404270
# std    1.727592e+03       6.522660        0.491770          3.936211
# min    1.000001e+06       0.000000        0.000000          1.000000
# 25%    1.001516e+06       2.000000        0.000000          1.000000
# 50%    1.003077e+06       7.000000        0.000000          5.000000
# 75%    1.004478e+06      14.000000        1.000000          8.000000
# max    1.006040e+06      20.000000        1.000000         20.000000
#
#             Purchase
# count  550068.000000
# mean     9263.968713
# std      5023.065394
# min        12.000000
# 25%      5823.000000
# 50%      8047.000000
# 75%     12054.000000
# max     23961.000000

# %%
w.groupby("Gender")["Purchase"].describe()
# Out:
#            count         mean          std   min     25%     50%      75%  \
# Gender
# F       135809.0  8734.565765  4767.233289  12.0  5433.0  7914.0  11400.0
# M       414259.0  9437.526040  5092.186210  12.0  5863.0  8098.0  12454.0
#
#             max
# Gender
# F       23959.0
# M       23961.0

# %%
w["Gender"].value_counts(normalize=True)*100
# Out:
# M    75.310507
# F    24.689493
# Name: Gender, dtype: float64

# %%
w.groupby(['Gender']).sum().plot(kind='pie', y='Purchase', autopct='%1.0f%%', startangle=60)
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# Non-Graphical Analysis: Value counts and unique attribu

# %%
w["User_ID"].nunique()
# Out:
# 5891

# %%
w["User_ID"].value_counts()
# Out:
# 1001680    1026
# 1004277     979
# 1001941     898
# 1001181     862
# 1000889     823
#            ...
# 1002690       7
# 1002111       7
# 1005810       7
# 1004991       7
# 1000708       6
# Name: User_ID, Length: 5891, dtype: int64

# %%
w["Product_ID"].value_counts()
# Out:
# P00265242    1880
# P00025442    1615
# P00110742    1612
# P00112142    1562
# P00057642    1470
#              ...
# P00314842       1
# P00298842       1
# P00231642       1
# P00204442       1
# P00066342       1
# Name: Product_ID, Length: 3631, dtype: int64

# %%
w["Age"].value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
w["Occupation"].value_counts()
# Out:
# 4     72308
# 0     69638
# 7     59133
# 1     47426
# 17    40043
# 20    33562
# 12    31179
# 14    27309
# 2     26588
# 16    25371
# 6     20355
# 3     17650
# 10    12930
# 5     12177
# 15    12165
# 11    11586
# 19     8461
# 13     7728
# 18     6622
# 9      6291
# 8      1546
# Name: Occupation, dtype: int64

# %%
w["City_Category"].value_counts()
# Out:
# B    231173
# C    171175
# A    147720
# Name: City_Category, dtype: int64

# %%
w["Stay_In_Current_City_Years"].value_counts()
# Out:
# 1     193821
# 2     101838
# 3      95285
# 4+     84726
# 0      74398
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
w["Marital_Status"].value_counts()
# Out:
# 0    324731
# 1    225337
# Name: Marital_Status, dtype: int64

# %%
w["Product_Category"].value_counts().head()
# Out:
# 5     150933
# 1     140378
# 8     113925
# 11     24287
# 2      23864
# Name: Product_Category, dtype: int64

# %%
w["Purchase"].value_counts().head()
# Out:
# 7011    191
# 7193    188
# 6855    187
# 6891    184
# 7012    183
# Name: Purchase, dtype: int64

# %%
w.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category                 20
# Purchase                      18105
# dtype: int64

# %%
w["User_ID"].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
w["Product_ID"].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00370293',
#        'P00371644', 'P00370853'], dtype=object)

# %%
w["Occupation"].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
w["Product_Category"].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19], dtype=int64)

# %% [markdown]
# Visual Analysis - Univariate & Bivariate

# %% [markdown]
# For continuous variable(s): Distplot, countplot, histogram for univariate analysis

# %%
columns=['User_ID','Occupation', 'Marital_Status', 'Product_Category']
w[columns]=w[columns].astype('object')

# %%
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  object
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  object
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  object
#  8   Product_Category            550068 non-null  object
#  9   Purchase                    550068 non-null  int64
# dtypes: int64(1), object(9)
# memory usage: 42.0+ MB

# %% [markdown]
# Observations:
#
#     1. There are around 550068 rows & 10 columns of data listed.
#     2.There are 5891 unique users ,3631 products ,7 Age category,21 Occupation category ,3 city category and 20 product category listed.
#     3.There are no missing values / null values in the given data.
#     4.Mean of purchase amount for females is 8734.5 and males is 9437.52 which is quite less from 50th percentile found which is 7914 for females and 8098 for females.Max & Min purchase amount ranges from 12 - 23959 for females  & 12-23961 for males which is almost equal.
#     5. 75% of the data is male and 25% is females which is very less.Males are dominating in walmart purchases.
#     6.Though purchase amount range is similiar for both males and females , it is found that males buy the most expensive products from walmart compared to females.But females have more outliers which shows that there very less females who buy expensive products.
#     7.User_ID 1001680  bought 1026 maximum products & products P00265242,P00025442 P00110742 are the most purchased ones.
#     8.Age group 26-35 are active buyers followed by 35-45.
#     9.People with Occupation 4 being the highest,0,7,1 are all closely popular buyers.
#     10.People from City category B are popular buyers followed by C & A.
#     11. People who are staying for 1-2 years in the city are popular buyers.
#     12.Marital status 0 are the top buyers compared to 1.
#     13.Product category 5 being highest,1,8 are the popular ones.
#     14.Products with purchase amount from 6800-7100 are mostly bought.

# %%
#calculating percentage of purchases count across different categories 
# count of each category value/total count of variable

cat_col=["Gender","Age","Occupation","City_Category","Stay_In_Current_City_Years","Marital_Status"]

w[cat_col].melt().groupby(by=["variable","value"])[["value"]].count()/len(w)
# Out:
#                                      value
# variable                   value
# Age                        0-17   0.027455
#                            18-25  0.181178
#                            26-35  0.399200
#                            36-45  0.199999
#                            46-50  0.083082
#                            51-55  0.069993
#                            55+    0.039093
# City_Category              A      0.268549
#                            B      0.420263
#                            C      0.311189
# Gender                     F      0.246895
#                            M      0.753105
# Marital_Status             0      0.590347
#                            1      0.409653
# Occupation                 0      0.126599
#                            1      0.086218
#                            2      0.048336
#                            3      0.032087
#                            4      0.131453
#                            5      0.022137
# ...

# %% [markdown]
# 1. 40% of the purchase done by aged 26-35 and 78% purchase are done by the customers aged between the age 18-45 (40%: 26-35, 18%: 18-25, 20%: 36-45)
# 2. 75% of the purchase count are done by Male and 25% by Female
# 3. 60% Single, 40% Married contributes to the purchase count.
# 4. 35% Staying in the city from 1 year, 18% from 2 years, 17% from 3 years
# 5.Occupation 4 with 13% and 0 with 12% are the highest whereas other occupations aree significantly distributed.

# %%
#calculating distribution of people/users among different categories

# %%
w1=w.groupby("User_ID")["Age"].unique()
w1.value_counts()/len(w1)
# Out:
# [26-35]    0.348498
# [36-45]    0.198099
# [18-25]    0.181463
# [46-50]    0.090137
# [51-55]    0.081650
# [55+]      0.063147
# [0-17]     0.037006
# Name: Age, dtype: float64

# %% [markdown]
# There are 34% people in age group [26-35] purchasing 40% of purchase counts.

# %%
w2=w.groupby(['User_ID'])['Gender'].unique()
w2.value_counts()/len(w2)
# Out:
# [M]    0.717196
# [F]    0.282804
# Name: Gender, dtype: float64

# %% [markdown]
# 71% of total population are males and they 75% of purchase count and 28% females purchase 25% purchase count.

# %%
w3=w.groupby(['User_ID'])['Marital_Status'].unique()
w3.value_counts()/len(w3)
# Out:
# [0]    0.580037
# [1]    0.419963
# Name: Marital_Status, dtype: float64

# %% [markdown]
# 58% are single and they contribute to 60% purchase count and 41% married people to 40% of purchase count.

# %%
w4=w.groupby(['User_ID'])['City_Category'].unique()
w4.value_counts()/len(w4)
# Out:
# [C]    0.532847
# [B]    0.289764
# [A]    0.177389
# Name: City_Category, dtype: float64

# %% [markdown]
# Though 53% people are C city category ,they are 31% of purchase count where as B covers only 28% but they have 42% of total purchase count.

# %%
#finding proportions or percentages within each row (2544/147720 = 0.0172222)
pd.crosstab(index=w["City_Category"],columns=w["Age"],margins=True,normalize="index")
# Out:
# Age                0-17     18-25     26-35     36-45     46-50     51-55  \
# City_Category
# A              0.017222  0.186400  0.499222  0.180185  0.051496  0.041288
# B              0.023511  0.187076  0.396171  0.205898  0.088272  0.076743
# C              0.041612  0.168705  0.316974  0.209131  0.103333  0.085649
# All            0.027455  0.181178  0.399200  0.199999  0.083082  0.069993
#
# Age                 55+
# City_Category
# A              0.024188
# B              0.022330
# C              0.074596
# All            0.039093

# %% [markdown]
#  we can conclude though B & A has less percentage population than C they both have highest purchase counts.

# %%
#purchase percentage along gender category

gen_percent=pd.DataFrame(w.groupby("Gender")["Purchase"].sum())
gen_percent["Percent"]=(gen_percent["Purchase"]/gen_percent["Purchase"].sum())*100
gen_percent
# Out:
#           Purchase    Percent
# Gender
# F       1186232642  23.278576
# M       3909580100  76.721424

# %%
#purchase percentage along Age category

age_percent=pd.DataFrame(w.groupby("Age")["Purchase"].sum())
age_percent["Percent"]=(age_percent["Purchase"]/age_percent["Purchase"].sum())*100
age_percent
# Out:
#          Purchase    Percent
# Age
# 0-17    134913183   2.647530
# 18-25   913848675  17.933325
# 26-35  2031770578  39.871374
# 36-45  1026569884  20.145361
# 46-50   420843403   8.258612
# 51-55   367099644   7.203947
# 55+     200767375   3.939850

# %%
#purchase percentage along Occupation category

occ_percent=pd.DataFrame(w.groupby("Occupation")["Purchase"].sum())
occ_percent["Percent"]=(occ_percent["Purchase"]/occ_percent["Purchase"].sum())*100
occ_percent
# Out:
#              Purchase    Percent
# Occupation
# 0           635406958  12.469198
# 1           424614144   8.332609
# 2           238028583   4.671062
# 3           162002168   3.179123
# 4           666244484  13.074352
# 5           113649759   2.230258
# 6           188416784   3.697482
# 7           557371587  10.937835
# 8            14737388   0.289206
# 9            54340046   1.066367
# 10          115844465   2.273327
# 11          106751618   2.094889
# 12          305449446   5.994126
# 13           71919481   1.411345
# 14          259454692   5.091527
# 15          118960211   2.334470
# 16          238346955   4.677310
# 17          393281453   7.717738
# 18           60721461   1.191595
# 19           73700617   1.446298
# 20          296570442   5.819885

# %%
#purchase percentage along City category

cc_percent=pd.DataFrame(w.groupby("City_Category")["Purchase"].sum())
cc_percent["Percent"]=(cc_percent["Purchase"]/cc_percent["Purchase"].sum())*100
cc_percent
# Out:
#                  Purchase    Percent
# City_Category
# A              1316471661  25.834381
# B              2115533605  41.515136
# C              1663807476  32.650483

# %% [markdown]
# # Univariate analysis

# %%
sns.distplot(w["Purchase"],color='g')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 1. We can see purchase value between 5000 and 10000 have higher count. From the initial observation we have already seen the mean and median is 9263 and 8047 respectively. Also, we can see there are outliers in the data.

# %%
sns.distplot(w["Product_Category"],color='g')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Density'>

# %% [markdown]
# To represent above findings, prod.category 5,1 & 8 are the bought mostly.

# %%
sns.boxplot(x="Gender",y="Purchase",data=w)
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase'>

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(15,9))
sns.countplot(data=w,x=w["Gender"],ax=axs[0,0])
sns.countplot(data=w,x=w["Age"],ax=axs[0,1])
sns.countplot(data=w,x=w["City_Category"],ax=axs[1,0])
sns.countplot(data=w,x=w["Occupation"],ax=axs[1,1])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# # Bivariate Analysis

# %%
w
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                               2               0                 3      8370
# ...

# %%
fig,axs=plt.subplots(nrows=1,ncols=2,figsize=(15,6))
sns.histplot(data=w[w["Gender"]=="M"]["Purchase"],ax=axs[0]).set_title("Male Spending")
sns.histplot(data=w[w["Gender"]=="F"]["Purchase"],ax=axs[1]).set_title("Female Spending")
# Out:
# Text(0.5, 1.0, 'Female Spending')

# %% [markdown]
# From the histplot , both male and female people purchase between 5000-10000.

# %%
fig,axs=plt.subplots(nrows=3,ncols=2,figsize=(15,9))
sns.boxplot(x="Gender",y="Purchase",data=w,ax=axs[0,0])
sns.boxplot(x="Age",y="Purchase",data=w,ax=axs[0,1])
sns.boxplot(x="Occupation",y="Purchase",data=w,ax=axs[1,0])
sns.boxplot(x="City_Category",y="Purchase",data=w,ax=axs[1,1])
sns.boxplot(x="Stay_In_Current_City_Years",y="Purchase",data=w,ax=axs[2,0])
sns.boxplot(x="Marital_Status",y="Purchase",data=w,ax=axs[2,1])
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Purchase'>

# %%
w.groupby("Gender").agg({"Purchase":"sum"})
# Out:
#           Purchase
# Gender
# F       1186232642
# M       3909580100

# %%
w.Gender.value_counts()
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %%
w[w["User_ID"]== 1000001]["Gender"].value_counts()
# Out:
# F    35
# Name: Gender, dtype: int64

# %% [markdown]
# # Multivariate Analysis

# %%
hue_attr=["Age","City_Category","Stay_In_Current_City_Years","Marital_Status"]

fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(20,10))
count=0

for i in range(2):
    for j in range(2):
        sns.boxplot(x=w["Gender"],y=w["Purchase"],hue=hue_attr[count],data=w,ax=axs[i,j],)
        count+= 1

plt.show()

# %%
columns=['User_ID','Occupation', 'Marital_Status', 'Product_Category']
w[columns]=w[columns].astype('int64')

# %%
sns.heatmap(w.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # correlation of any of the pair is not significant.

# %%
sns.pairplot(data=w)

# %%
#finding count of males & females and there total purchase amount removing duplicates.

user_total=w.groupby(["User_ID","Gender"])[["Purchase"]].sum()
user_total=user_total.reset_index()
user_total
# Out:
#       User_ID Gender  Purchase
# 0     1000001      F    334093
# 1     1000002      M    810472
# 2     1000003      M    341635
# 3     1000004      M    206468
# 4     1000005      M    821001
# ...       ...    ...       ...
# 5886  1006036      F   4116058
# 5887  1006037      F   1119538
# 5888  1006038      F     90034
# 5889  1006039      F    590319
# 5890  1006040      M   1653299
#
# [5891 rows x 3 columns]

# %%
#avg purchase amount for male & female
avgamt=pd.DataFrame(user_total.groupby(["Gender"])[["Purchase"]].mean())
avgamt.reset_index()
# Out:
#   Gender       Purchase
# 0      F  712024.394958
# 1      M  925344.402367

# %%
totamt=pd.DataFrame(user_total.groupby(["Gender"])["Purchase"].sum())
totamt
# Out:
#           Purchase
# Gender
# F       1186232642
# M       3909580100

# %%
columns=['User_ID','Occupation', 'Marital_Status', 'Product_Category']
w[columns]=w[columns].astype('object')

# %%
print(user_total.columns)
# Out:
# Index(['Purchase'], dtype='object')

# %%
# Purchase distribution across gender
fig,axs= plt.subplots(nrows=1,ncols=2,figsize=(15,6))

sns.histplot(data=user_total[user_total['Gender']=='F']['Purchase'],ax=axs[0]).set_title("Avg purchases by females")
sns.histplot(data=user_total[user_total['Gender']=='M']['Purchase'],ax=axs[1]).set_title("Avg purchases by males")
# Out:
# Text(0.5, 1.0, 'Avg purchases by males')

# %%
avgamt_male=user_total[user_total['Gender']=='M']
avgamt_female=data=user_total[user_total['Gender']=='F']

# %%
#finding purchase amount distribution for males & females 

sample_size = 1000

num_rep=1000

male_means = []
female_means=[]

for i in range(num_rep):    
    male_mean=avgamt_male.sample(sample_size,replace=True)['Purchase'].mean()
    female_mean=avgamt_female.sample(sample_size,replace=True)['Purchase'].mean()
    
    male_means.append(male_mean)
    female_means.append(female_mean)

# %%
#fig,axs=plt.subplots(nrows=1,ncols=2,figsize=(15,9))

#sns.histplot(data=male_means,ax=axs[0]).set_title("Purchase_amount distribution by males for 1000 samples")
#sns.histplot(data=female_means,ax=axs[1]).set_title("Purchase_amount distribution by females 1000 samples")


sns.histplot(data=male_means,color='b')
sns.histplot(data=female_means)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# The mean value of samples for both males and females are same for a sample of 1000.

# %%
#Calculating 90% confidence interval for sample size 1000:

z= 1.645

sample_men=np.mean(male_means)
sample_women=np.mean(female_means)

stdsample_men=pd.Series(male_means).std()
stdsample_women=pd.Series(female_means).std()

stderr_men = stdsample_men/np.sqrt(1000)
stderr_fem=stdsample_women/np.sqrt(1000)

upper_m = sample_men+(z * stderr_men)
upper_f = sample_women+(z* stderr_fem)

lower_m = sample_men-(z * stderr_men)
lower_f = sample_women-(z* stderr_fem)

print("Male C.I",[lower_m,upper_m])
print("Female C.I",[lower_f,upper_f])
# Out:
# Male C.I [924806.3497901396, 927896.6721298604]
# Female C.I [709678.5208199603, 712401.3197540395]

# %% [markdown]
# From above observations,we can say that for 90% CI
#
# Avg amount spent on Male C.I [924806.3497901396, 927896.6721298604]
# Avg amount spent on Female C.I [709678.5208199603, 712401.3197540395]

# %%
#Calculating 95% confidence interval for sample size 1000:

z= 1.96

sample_men=np.mean(male_means)
sample_women=np.mean(female_means)

stdsample_men=pd.Series(male_means).std()
stdsample_women=pd.Series(female_means).std()

stderr_men = stdsample_men/np.sqrt(1000)
stderr_fem=stdsample_women/np.sqrt(1000)

upper_m = sample_men+(z * stderr_men)
upper_f = sample_women+(z* stderr_fem)

lower_m = sample_men-(z * stderr_men)
lower_f = sample_women-(z* stderr_fem)

print("Male C.I",[lower_m,upper_m])
print("Female C.I",[lower_f,upper_f])
# Out:
# Male C.I [924510.467863996, 928192.5540560039]
# Female C.I [709417.8273049953, 712662.0132690045]

# %% [markdown]
# From above observations,we can say that for 95% CI
#
# Avg amount spent on Male C.I [924510.467863996, 928192.5540560039]
# Avg amount spent on Female C.I [709417.8273049953, 712662.0132690045]

# %%
#Calculating 99% confidence interval for sample size 1000:

z= 2.58

sample_men=np.mean(male_means)
sample_women=np.mean(female_means)

stdsample_men=pd.Series(male_means).std()
stdsample_women=pd.Series(female_means).std()

stderr_men = stdsample_men/np.sqrt(1000)
stderr_fem=stdsample_women/np.sqrt(1000)

upper_m = sample_men+(z * stderr_men)
upper_f = sample_women+(z* stderr_fem)

lower_m = sample_men-(z * stderr_men)
lower_f = sample_women-(z* stderr_fem)

print("Male C.I",[lower_m,upper_m])
print("Female C.I",[lower_f,upper_f])
# Out:
# Male C.I [923928.0970887295, 928774.9248312705]
# Female C.I [708904.7162596673, 713175.1243143325]

# %% [markdown]
# From above observations,we can say that for 99% CI
#
# Avg amount spent on Male C.I [923928.0970887295, 928774.9248312705]
# Avg amount spent on Female C.I [708904.7162596673, 713175.1243143325]

# %%
#finding purchase amount distribution for males & females 

sample_size = 1500

num_rep=1000

male_means = []
female_means=[]

for i in range(num_rep):    
    male_mean=avgamt_male.sample(sample_size,replace=True)['Purchase'].mean()
    female_mean=avgamt_female.sample(sample_size,replace=True)['Purchase'].mean()
    
    male_means.append(male_mean)
    female_means.append(female_mean)

# %%
#fig,axs=plt.subplots(nrows=1,ncols=2,figsize=(15,9))

#sns.histplot(data=male_means,ax=axs[0]).set_title("Purchase_amount distribution by males for 1500 samples")
#sns.histplot(data=female_means,ax=axs[1]).set_title("Purchase_amount distribution by females 1500 samples")

sns.histplot(data=male_means,color='g')
sns.histplot(data=female_means)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# #Calculating 90% confidence interval for sample size 1500:
#
# z= 1.645
#
# sample_men=np.mean(male_means)
# sample_women=np.mean(female_means)
#
# stdsample_men=pd.Series(male_means).std()
# stdsample_women=pd.Series(female_means).std()
#
# stderr_men = stdsample_men/np.sqrt(1500)
# stderr_fem=stdsample_women/np.sqrt(1500)
#
# upper_m = sample_men+(z * stderr_men)
# upper_f = sample_women+(z* stderr_fem)
#
# lower_m = sample_men-(z * stderr_men)
# lower_f = sample_women-(z* stderr_fem)
#
# print("Male C.I",[lower_m,upper_m])
# print("Female C.I",[lower_f,upper_f])

# %% [markdown]
# From above observations,we can say that for 90% CI
#
# Avg amount spent on Male C.I [925222.8555996056, 927331.1191097278]
# Avg amount spent on Female C.I [710699.8682854358, 712504.5899265643]

# %%
#Calculating 95% confidence interval for sample size 1500:

z= 1.96

sample_men=np.mean(male_means)
sample_women=np.mean(female_means)

stdsample_men=pd.Series(male_means).std()
stdsample_women=pd.Series(female_means).std()

stderr_men = stdsample_men/np.sqrt(1500)
stderr_fem=stdsample_women/np.sqrt(1500)

upper_m = sample_men+(z * stderr_men)
upper_f = sample_women+(z* stderr_fem)

lower_m = sample_men-(z * stderr_men)
lower_f = sample_women-(z* stderr_fem)

print("Male C.I",[lower_m,upper_m])
print("Female C.I",[lower_f,upper_f])
# Out:
# Male C.I [925021.0005826791, 927532.9741266543]
# Female C.I [710527.0757878809, 712677.3824241192]

# %% [markdown]
# From above observations,we can say that for 95% CI
#
# Avg amount spent on Male C.I [925021.0005826791, 927532.9741266543]
# Avg amount spent on Female C.I [710527.0757878809, 712677.3824241192]

# %%
#Calculating 99% confidence interval for sample size 1500:

z= 2.58

sample_men=np.mean(male_means)
sample_women=np.mean(female_means)

stdsample_men=pd.Series(male_means).std()
stdsample_women=pd.Series(female_means).std()

stderr_men = stdsample_men/np.sqrt(1500)
stderr_fem=stdsample_women/np.sqrt(1500)

upper_m = sample_men+(z * stderr_men)
upper_f = sample_women+(z* stderr_fem)

lower_m = sample_men-(z * stderr_men)
lower_f = sample_women-(z* stderr_fem)

print("Male C.I",[lower_m,upper_m])
print("Female C.I",[lower_f,upper_f])
# Out:
# Male C.I [924623.6986446013, 927930.2760647321]
# Female C.I [710186.9762688841, 713017.4819431159]

# %% [markdown]
# From above observations,we can say that for 95% CI
#
# Avg amount spent on Male C.I [924623.6986446013, 927930.2760647321]
# Avg amount spent on Female C.I [710186.9762688841, 713017.4819431159]

# %%
#Finding CI for Marital Status

avgamt_ms=w.groupby(["User_ID","Marital_Status"])[["Purchase"]].sum()
avgamt_ms=avgamt_ms.reset_index()
avgamt_ms
# Out:
#       User_ID  Marital_Status  Purchase
# 0     1000001               0    334093
# 1     1000002               0    810472
# 2     1000003               0    341635
# 3     1000004               1    206468
# 4     1000005               1    821001
# ...       ...             ...       ...
# 5886  1006036               1   4116058
# 5887  1006037               0   1119538
# 5888  1006038               0     90034
# 5889  1006039               1    590319
# 5890  1006040               0   1653299
#
# [5891 rows x 3 columns]

# %%
avgamt_ms.groupby("Marital_Status")[["Purchase"]].mean()
# Out:
#                      Purchase
# Marital_Status
# 0               880575.781972
# 1               843526.796686

# %%
sample_size=1000

num_rep= 1000

married=avgamt_ms[avgamt_ms["Marital_Status"]==1]
unmarried=avgamt_ms[avgamt_ms["Marital_Status"]==0]

avg_mar=[]
avg_unmar=[]
for i in range(num_rep):
    avg_married=married.sample(sample_size,replace=True)["Purchase"].mean()
    avg_unmarried=unmarried.sample(sample_size,replace=True)["Purchase"].mean()
    
    avg_mar.append(avg_married)
    avg_unmar.append(avg_unmarried)
    
    
#fig,axs=plt.subplots(nrows=1,ncols=2,figsize=(15,9))

#sns.histplot(data=avg_mar,ax=axs[0]).set_title("Average purchase amount for married people")
#sns.histplot(data=avg_unmar,ax=axs[1]).set_title("Average purchase amount for unmarried people")
sns.histplot(data=avg_mar,color='r')
sns.histplot(data=avg_unmar)
plt.show()

# %% [markdown]
# Means of average purchase amount seems to be close to population mean for both married & unmarried people using CLT.

# %%
#Calculating 90% confidence interval for sample size 1000:

z= 1.645

sample_mar=np.mean(avg_mar)
sample_unmar=np.mean(avg_unmar)

stdsample_mar=pd.Series(avg_mar).std()
stdsample_unmar=pd.Series(avg_unmar).std()

stderr_mar = stdsample_mar/np.sqrt(1000)
stderr_unmar=stdsample_unmar/np.sqrt(1000)

upper_m = sample_mar+(z * stderr_mar)
upper_um = sample_unmar+(z* stderr_unmar)

lower_m = sample_mar-(z * stderr_mar)
lower_um = sample_unmar-(z* stderr_unmar)

print("Married C.I",[lower_m,upper_m])
print("Unmarried C.I",[lower_um,upper_um])
# Out:
# Married C.I [841907.3171197487, 844990.8905902513]
# Unmarried C.I [876748.5235452075, 879883.8293467925]

# %%
#Calculating 95% confidence interval for sample size 1000:

z= 1.96

sample_mar=np.mean(avg_mar)
sample_unmar=np.mean(avg_unmar)

stdsample_mar=pd.Series(avg_mar).std()
stdsample_unmar=pd.Series(avg_unmar).std()

stderr_mar = stdsample_mar/np.sqrt(1000)
stderr_unmar=stdsample_unmar/np.sqrt(1000)

upper_m = sample_mar+(z * stderr_mar)
upper_um = sample_unmar+(z* stderr_unmar)

lower_m = sample_mar-(z * stderr_mar)
lower_um = sample_unmar-(z* stderr_unmar)

print("Married C.I",[lower_m,upper_m])
print("Unmarried C.I",[lower_um,upper_um])
# Out:
# Married C.I [841612.0813619345, 845286.1263480654]
# Unmarried C.I [876448.3346918642, 880184.0182001358]

# %%
#Calculating 99% confidence interval for sample size 1000:

z= 2.58

sample_mar=np.mean(avg_mar)
sample_unmar=np.mean(avg_unmar)

stdsample_mar=pd.Series(avg_mar).std()
stdsample_unmar=pd.Series(avg_unmar).std()

stderr_mar = stdsample_mar/np.sqrt(1000)
stderr_unmar=stdsample_unmar/np.sqrt(1000)

upper_m = sample_mar+(z * stderr_mar)
upper_um = sample_unmar+(z* stderr_unmar)

lower_m = sample_mar-(z * stderr_mar)
lower_um = sample_unmar-(z* stderr_unmar)

print("Married C.I",[lower_m,upper_m])
print("Unmarried C.I",[lower_um,upper_um])
# Out:
# Married C.I [841030.9824100465, 845867.2252999535]
# Unmarried C.I [875857.4867900457, 880774.8661019542]

# %%
# Finding average purchase amount according to different age groups

age_gp=w.groupby(["User_ID","Age"])[["Purchase"]].sum()
age_gp=age_gp.reset_index()
age_gp
# Out:
#       User_ID    Age  Purchase
# 0     1000001   0-17    334093
# 1     1000002    55+    810472
# 2     1000003  26-35    341635
# 3     1000004  46-50    206468
# 4     1000005  26-35    821001
# ...       ...    ...       ...
# 5886  1006036  26-35   4116058
# 5887  1006037  46-50   1119538
# 5888  1006038    55+     90034
# 5889  1006039  46-50    590319
# 5890  1006040  26-35   1653299
#
# [5891 rows x 3 columns]

# %%
w.Age.unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
age_gp["Age"].value_counts()
# Out:
# 26-35    2053
# 36-45    1167
# 18-25    1069
# 46-50     531
# 51-55     481
# 55+       372
# 0-17      218
# Name: Age, dtype: int64

# %%
age_group=['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25']


sample_size = 200
num_rep=1000

age_cat={}
for i in age_group:
    age_cat[i]=[]
    
for i in age_group:
    for j in range(num_rep):
        age_mean=age_gp[age_gp["Age"]==i].sample(sample_size,replace=True)["Purchase"].mean()
        age_cat[i].append(age_mean)
        
fig,axs=plt.subplots(nrows=4,ncols=2,figsize=(20,15))

sns.histplot(age_cat['26-35'],bins=35,ax=axs[0,0])
sns.histplot(age_cat['36-45'],bins=35,ax=axs[0,1])
sns.histplot(age_cat['18-25'],bins=35,ax=axs[1,0])
sns.histplot(age_cat['46-50'],bins=35,ax=axs[1,1])
sns.histplot(age_cat['51-55'],bins=35,ax=axs[2,0])
sns.histplot(age_cat['55+'],bins=35,ax=axs[2,1])
sns.histplot(age_cat['0-17'],bins=35,ax=axs[3,0])
# Out:
# <Axes: ylabel='Count'>

# %%
#Calculating 90% confidence interval for sample size 200:

population_mean = {}

for i in age_group:    
        population_mean[i]=[]
        pop_mean=age_gp[age_gp["Age"]==i]["Purchase"].mean()
        population_mean[i].append(pop_mean)
        print("Population mean{}".format(i),population_mean[i])
        
        
sample_size = 200
num_rep=1000

age_cat={}
for i in age_group:
    age_cat[i]=[]
    
for i in age_group:
    for j in range(num_rep):
        age_mean=age_gp[age_gp["Age"]==i].sample(sample_size,replace=True)["Purchase"].mean()
        age_cat[i].append(age_mean)
    z= 1.645
    age_grp=age_cat[i]
    stderr_age = pd.Series(age_grp).std()/np.sqrt(200)
    age_mean=np.mean(age_grp)
    upper_a = age_mean+(z * stderr_age)
    lower_a = age_mean-(z * stderr_age)
    print("Age group {} C.I".format(i),[lower_a,upper_a])
# Out:
# Population mean0-17 [618867.8119266055]
# Population mean55+ [539697.2446236559]
# Population mean26-35 [989659.3170969313]
# Population mean46-50 [792548.7815442561]
# Population mean51-55 [763200.9230769231]
# Population mean36-45 [879665.7103684661]
# Population mean18-25 [854863.119738073]
# Age group 0-17 C.I [613690.8429395236, 625439.6890404763]
# Age group 55+ C.I [535024.941836115, 545079.3888438852]
# Age group 26-35 C.I [979066.048334488, 995465.5953255119]
# Age group 46-50 C.I [788223.4453245748, 803351.6856254253]
# Age group 51-55 C.I [758626.8004405343, 771369.7948494656]
# Age group 36-45 C.I [869893.1039918684, 885567.3987281315]
# Age group 18-25 C.I [847233.285992849, 861525.328337151]

# %%
#Calculating 95% confidence interval for sample size 200:

population_mean = {}

for i in age_group:    
        population_mean[i]=[]
        pop_mean=age_gp[age_gp["Age"]==i]["Purchase"].mean()
        population_mean[i].append(pop_mean)
        print("Population mean{}".format(i),population_mean[i])
        
age_cat={}
for i in age_group:
    age_cat[i]=[]
    
for i in age_group:
        age_grp=age_gp[age_gp["Age"]==i]
        z= 1.96
        stderr_age = age_grp["Purchase"].std()/np.sqrt(200)
        age_mean=age_grp["Purchase"].mean()
        upper_a = age_mean+(z * stderr_age)
        lower_a = age_mean-(z * stderr_age)
        print("Age group {} C.I".format(i),[lower_a,upper_a])
# Out:
# Population mean0-17 [618867.8119266055]
# Population mean55+ [539697.2446236559]
# Population mean26-35 [989659.3170969313]
# Population mean46-50 [792548.7815442561]
# Population mean51-55 [763200.9230769231]
# Population mean36-45 [879665.7103684661]
# Population mean18-25 [854863.119738073]
# Age group 0-17 C.I [523646.6255593566, 714088.9982938544]
# Age group 55+ C.I [454119.0387054091, 625275.4505419028]
# Age group 26-35 C.I [846685.4483371936, 1132633.185856669]
# Age group 46-50 C.I [663754.5281023637, 921343.0349861486]
# Age group 51-55 C.I [653390.6625513788, 873011.1836024674]
# Age group 36-45 C.I [743625.6092732752, 1015705.811463657]
# Age group 18-25 C.I [731798.5232461436, 977927.7162300023]

# %%
#Calculating 99% confidence interval for sample size 200:

population_mean = {}

for i in age_group:    
        population_mean[i]=[]
        pop_mean=age_gp[age_gp["Age"]==i]["Purchase"].mean()
        population_mean[i].append(pop_mean)
        print("Population mean{}".format(i),population_mean[i])
        
age_cat={}
for i in age_group:
    age_cat[i]=[]
    
for i in age_group:
        age_grp=age_gp[age_gp["Age"]==i]
        z= 2.58
        stderr_age = age_grp["Purchase"].std()/np.sqrt(200)
        age_mean=age_grp["Purchase"].mean()
        upper_a = age_mean+(z * stderr_age)
        lower_a = age_mean-(z * stderr_age)
        print("Age group {} C.I".format(i),[lower_a,upper_a])
# Out:
# Population mean0-17 [618867.8119266055]
# Population mean55+ [539697.2446236559]
# Population mean26-35 [989659.3170969313]
# Population mean46-50 [792548.7815442561]
# Population mean51-55 [763200.9230769231]
# Population mean36-45 [879665.7103684661]
# Population mean18-25 [854863.119738073]
# Age group 0-17 C.I [493525.63803502277, 744209.9858181883]
# Age group 55+ C.I [427048.38173126976, 652346.1075160421]
# Age group 26-35 C.I [801459.0204642153, 1177859.6137296471]
# Age group 46-50 C.I [623013.4887482957, 962084.0743402166]
# Age group 51-55 C.I [618654.7638137066, 907747.0823401397]
# Age group 36-45 C.I [700592.5160696944, 1058738.9046672378]
# Age group 18-25 C.I [692869.9263966557, 1016856.3130794902]

# %% [markdown]
# In all the above CI for different age group categories , the population mean falls under the the lower and upper limit of C.I found using CLT for different age groups.
#
#
# Also , as confidence interval increases upper limit tends to increase.
